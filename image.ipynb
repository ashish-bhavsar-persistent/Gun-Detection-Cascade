# %% [markdown]
# <a href="https://colab.research.google.com/github/ashish-bhavsar-persistent/Gun-Detection-Cascade/blob/master/image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Setting Up Env

# %%
# !pwd
# %cd /content
# !rm -rf *
# !git clone https://github.com/ashish-bhavsar-persistent/Gun-Detection-Cascade.git
# %cd Gun-Detection-Cascade
# !pwd
# !ls
# Out:
# /content/Gun-Detection-Cascade
# /content
# Cloning into 'Gun-Detection-Cascade'...
# remote: Enumerating objects: 661, done.
# remote: Counting objects: 100% (661/661), done.
# remote: Compressing objects: 100% (514/514), done.
# remote: Total 19484 (delta 155), reused 653 (delta 147), pack-reused 18823
# Receiving objects: 100% (19484/19484), 167.41 MiB | 39.31 MiB/s, done.
# Resolving deltas: 100% (376/376), done.
# /content/Gun-Detection-Cascade
# /content/Gun-Detection-Cascade
#  bg.txt		        gun.jpg       Raw		 uglies
#  DownloadImage.py       image.ipynb  'Resize Image.py'
#  generateNegImages.py   neg	      ThreadEx.py

# %% [markdown]
# # 2. Execute Python Code

# %%
# !python DownloadImage.py

# %% [markdown]
# # 3. Count Number of Files in Neg Directory

# %%
# !pwd
# !ls
# %cd /content/Gun-Detection-Cascade/neg
# !git config --global user.email "ashishkumar_bhavsar@persistent.com"
# !git config --global user.name "ashish-bhavsar-persistent"
# !ls -1 | wc -l
# %cd ..
# !git pull
# !git add .
# !git commit -m "Training Done"
# !git push https://ashish-bhavsar-persistent:Ashish%21%40%23%245@github.com/ashish-bhavsar-persistent/Gun-Detection-Cascade.git --all

# %%
# !git pull
# !ls

# %%
# !apt-get update
# !apt-get upgrade
# !apt-get install build-essential
# !apt-get install cmake git libgtk2.0-dev pkg-config libavcodec-dev libavformat-dev libswscale-dev
# !sudo apt-get install python-dev python-numpy libtbb2 libtbb-dev libjpeg-dev libpng-dev libtiff-dev libdc1394-22-dev
# !apt-get install libopencv-dev

# %%
# !sudo apt-get install opencv-data 
# !sudo apt-get install libopencv-dev

# %%
# !opencv_createsamples -img gun.jpg -bg bg.txt -info info/info.lst -pngoutput info -maxxangle 0.5 -maxyangle 0.5 -maxzangle 0.5 -num 2000

# %%
# !opencv_createsamples -info info/info.lst -num 2000 -w 20 -h 20 -vec positives.vec
# Out:
# Info file name: info/info.lst
# Img file name: (NULL)
# Vec file name: positives.vec
# BG  file name: (NULL)
# Num: 2000
# BG color: 0
# BG threshold: 80
# Invert: FALSE
# Max intensity deviation: 40
# Max x angle: 1.1
# Max y angle: 1.1
# Max z angle: 0.5
# Show samples: FALSE
# Width: 20
# Height: 20
# Max Scale: -1
# Create training samples from images collection...
# Done. Created 2000 samples

# %%
# !opencv_traincascade -data data -vec positives.vec -bg bg.txt -numPos 900 -numNeg 2000 -numStages 10 -w 20 -h 20 -featureType LBP -precalcValBufSize 2048 -precalcIdxBufSize 2048  -featureType HAAR -minHitRate 0.999 -maxFalseAlarmRate 0.5
# Out:
# PARAMETERS:
# cascadeDirName: data
# vecFileName: positives.vec
# bgFileName: bg.txt
# numPos: 900
# numNeg: 2000
# numStages: 10
# precalcValBufSize[Mb] : 2048
# precalcIdxBufSize[Mb] : 2048
# acceptanceRatioBreakValue : -1
# stageType: BOOST
# featureType: HAAR
# sampleWidth: 20
# sampleHeight: 20
# boostType: GAB
# minHitRate: 0.999
# maxFalseAlarmRate: 0.5
# weightTrimRate: 0.95
# maxDepth: 1
# maxWeakCount: 100
# mode: BASIC
# Number of unique features given windowSize [20,20] : 78460
#
# ===== TRAINING 0-stage =====
# <BEGIN
# POS count : consumed   900 : 900
# NEG count : acceptanceRatio    2000 : 1
# Precalculation time: 12
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2|        1|        1|
# +----+---------+---------+
# |   3|        1|   0.1035|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 0 minutes 34 seconds.
#
# ===== TRAINING 1-stage =====
# <BEGIN
# POS count : consumed   900 : 900
# NEG count : acceptanceRatio    2000 : 0.103504
# Precalculation time: 10
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        0|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 0 minutes 57 seconds.
#
# ===== TRAINING 2-stage =====
# <BEGIN
# POS count : consumed   900 : 900
# NEG count : acceptanceRatio    0 : 0
# Required leaf false alarm rate achieved. Branch training terminated.

# %%
# !rm -rf data
# !mkdir data
# !ls
# Out:
#  bg.txt		        gun.jpg       positives.vec	 uglies
#  data		        image.ipynb   Raw
#  DownloadImage.py       info	     'Resize Image.py'
#  generateNegImages.py   neg	      ThreadEx.py

# %%
rm -rf positives.vec
