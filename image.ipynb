# %% [markdown]
# <a href="https://colab.research.google.com/github/ashish-bhavsar-persistent/Gun-Detection-Cascade/blob/master/image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Setting Up Env

# %%
# !pwd
# %cd /content
# !git clone https://github.com/ashish-bhavsar-persistent/Gun-Detection-Cascade.git
# %cd Gun-Detection-Cascade
# !pwd
# !ls
# Out:
# /
# /content
# Cloning into 'Gun-Detection-Cascade'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 18 (delta 4), reused 14 (delta 3), pack-reused 0
# Unpacking objects: 100% (18/18), done.
# /content/Gun-Detection-Cascade
# /content/Gun-Detection-Cascade
# DownloadImage.py  image.ipynb  README.md

# %% [markdown]
# # 2. Execute Python Code

# %%
# !python DownloadImage.py

# %% [markdown]
# # 3. Count Number of Files in Neg Directory

# %%
# !pwd
# !ls
# %cd /content/Gun-Detection-Cascade/neg
# !git config --global user.email "ashishkumar_bhavsar@persistent.com"
# !git config --global user.name "ashish-bhavsar-persistent"
# !ls -1 | wc -l
# %cd ..
# !git pull
# !git add .
# !git commit -m "Model Trained"
# !git push https://ashish-bhavsar-persistent:Ashish%21%40%23%245@github.com/ashish-bhavsar-persistent/Gun-Detection-Cascade.git --all
# Out:
# /content/Gun-Detection-Cascade
#  bg.txt		    gun.png	  neg		     rifel.jpg
#  data		    image.ipynb   positives.vec      ThreadEx.py
#  DownloadImage.py   info	 'Resize Image.py'   uglies
# /content/Gun-Detection-Cascade/neg
# 3829
# /content/Gun-Detection-Cascade
# From https://github.com/ashish-bhavsar-persistent/Gun-Detection-Cascade
#    71461b4..b50f798  master     -> origin/master
# Already up to date.
# [master 5fb90a6] Model Trained
#  12 files changed, 10154 insertions(+)
#  create mode 100644 data/cascade.xml
#  create mode 100644 data/params.xml
#  create mode 100644 data/stage0.xml
#  create mode 100644 data/stage1.xml
#  create mode 100644 data/stage2.xml
#  create mode 100644 data/stage3.xml
#  create mode 100644 data/stage4.xml
#  create mode 100644 data/stage5.xml
#  create mode 100644 data/stage6.xml
#  create mode 100644 data/stage7.xml
#  create mode 100644 data/stage8.xml
#  create mode 100644 data/stage9.xml
# Counting objects: 15, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (15/15), done.
# Writing objects: 100% (15/15), 38.86 KiB | 1.94 MiB/s, done.
# Total 15 (delta 11), reused 0 (delta 0)
# remote: Resolving deltas: 100% (11/11), completed with 1 local object.
# To https://github.com/ashish-bhavsar-persistent/Gun-Detection-Cascade.git
#    b50f798..5fb90a6  master -> master

# %%
# !git pull
# !ls

# %%
# !apt-get update
# !apt-get upgrade
# !apt-get install build-essential
# !apt-get install cmake git libgtk2.0-dev pkg-config libavcodec-dev libavformat-dev libswscale-dev
# !sudo apt-get install python-dev python-numpy libtbb2 libtbb-dev libjpeg-dev libpng-dev libtiff-dev libjasper-dev libdc1394-22-dev
# !apt-get install libopencv-dev

# %%
# !opencv_createsamples -img gun.png -bg bg.txt -info info/info.lst -pngoutput info -maxxangle 0.5 -maxyangle 0.5 -maxzangle 0.5 -num 3800

# %%
# !opencv_createsamples -info info/info.lst -num 3800 -w 20 -h 20 -vec positives.vec

# %%
 # !opencv_traincascade -data data -vec positives.vec -bg bg.txt -numPos 3600 -numNeg 1800 -numStages 10 -w 20 -h 20
# Out:
# |   1|        1|        1|
# +----+---------+---------+
# |   2|        1|        1|
# +----+---------+---------+
# |   3|        1|        1|
# +----+---------+---------+
# |   4|        1|        1|
# +----+---------+---------+
# |   5|        1|        1|
# +----+---------+---------+
# |   6|        1|        1|
# +----+---------+---------+
# |   7|        1|        1|
# +----+---------+---------+
# |   8| 0.995833| 0.968333|
# +----+---------+---------+
# |   9| 0.995278| 0.957778|
# +----+---------+---------+
# |  10| 0.995556| 0.960556|
# +----+---------+---------+
# |  11| 0.995278|     0.95|
# +----+---------+---------+
# |  12| 0.997222|    0.965|
# +----+---------+---------+
# |  13| 0.996667| 0.940556|
# +----+---------+---------+
# |  14| 0.995278| 0.932222|
# +----+---------+---------+
# |  15| 0.996944| 0.940556|
# +----+---------+---------+
# |  16| 0.996389| 0.918333|
# +----+---------+---------+
# |  17| 0.995278| 0.912222|
# +----+---------+---------+
# |  18| 0.995556| 0.925556|
# +----+---------+---------+
# |  19| 0.995278| 0.916667|
# +----+---------+---------+
# |  20| 0.995278| 0.885556|
# +----+---------+---------+
# |  21| 0.995278| 0.906111|
# +----+---------+---------+
# |  22| 0.995278| 0.893889|
# +----+---------+---------+
# |  23| 0.995278| 0.889444|
# +----+---------+---------+
# |  24| 0.995278| 0.868889|
# +----+---------+---------+
# |  25| 0.995278| 0.858889|
# +----+---------+---------+
# |  26| 0.995278| 0.879444|
# +----+---------+---------+
# |  27| 0.995278| 0.869444|
# +----+---------+---------+
# |  28| 0.995278| 0.852778|
# +----+---------+---------+
# |  29| 0.995278| 0.847778|
# +----+---------+---------+
# |  30| 0.995278| 0.823889|
# +----+---------+---------+
# |  31| 0.995278| 0.816111|
# +----+---------+---------+
# |  32| 0.995278| 0.819444|
# +----+---------+---------+
# |  33| 0.995278| 0.830556|
# +----+---------+---------+
# |  34| 0.995278| 0.804444|
# +----+---------+---------+
# |  35| 0.995278| 0.781111|
# +----+---------+---------+
# |  36| 0.995278| 0.744444|
# +----+---------+---------+
# |  37| 0.995278|    0.735|
# +----+---------+---------+
# |  38| 0.995278| 0.757778|
# +----+---------+---------+
# |  39| 0.995278| 0.755556|
# +----+---------+---------+
# |  40| 0.995278| 0.745556|
# +----+---------+---------+
# |  41| 0.995278| 0.745556|
# +----+---------+---------+
# |  42| 0.995278| 0.715556|
# +----+---------+---------+
# |  43| 0.995278| 0.706111|
# +----+---------+---------+
# |  44| 0.995278| 0.709444|
# +----+---------+---------+
# |  45| 0.995278| 0.720556|
# +----+---------+---------+
# |  46| 0.995278| 0.711111|
# +----+---------+---------+
# |  47| 0.995278| 0.651667|
# +----+---------+---------+
# |  48| 0.995278|    0.675|
# +----+---------+---------+
# |  49| 0.995278| 0.668889|
# +----+---------+---------+
# |  50| 0.995278| 0.649444|
# +----+---------+---------+
# |  51| 0.995278| 0.675556|
# +----+---------+---------+
# |  52| 0.995278| 0.644444|
# +----+---------+---------+
# |  53| 0.995278| 0.643889|
# +----+---------+---------+
# |  54| 0.995278| 0.629444|
# +----+---------+---------+
# |  55| 0.995278| 0.613889|
# +----+---------+---------+
# |  56| 0.995278| 0.602778|
# +----+---------+---------+
# |  57| 0.995278| 0.595556|
# +----+---------+---------+
# |  58| 0.995278| 0.606667|
# +----+---------+---------+
# |  59| 0.995278| 0.582222|
# +----+---------+---------+
# |  60| 0.995278| 0.572222|
# +----+---------+---------+
# |  61| 0.995278| 0.554444|
# +----+---------+---------+
# |  62| 0.995278| 0.561667|
# +----+---------+---------+
# |  63| 0.995278|    0.565|
# +----+---------+---------+
# |  64| 0.995278| 0.554444|
# +----+---------+---------+
# |  65| 0.995278|    0.535|
# +----+---------+---------+
# |  66| 0.995278| 0.543333|
# +----+---------+---------+
# |  67| 0.995278| 0.508889|
# +----+---------+---------+
# |  68| 0.995278|     0.53|
# +----+---------+---------+
# |  69| 0.995278| 0.508889|
# +----+---------+---------+
# |  70| 0.995278| 0.501111|
# +----+---------+---------+
# |  71| 0.995278| 0.492222|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 1 hours 32 minutes 6 seconds.
#
# ===== TRAINING 6-stage =====
# <BEGIN
# POS count : consumed   3600 : 3709
# NEG count : acceptanceRatio    1800 : 0.0470367
# Precalculation time: 27
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2|        1|        1|
# +----+---------+---------+
# |   3|        1|        1|
# +----+---------+---------+
# |   4|        1|        1|
# +----+---------+---------+
# |   5|        1|        1|
# +----+---------+---------+
# |   6|        1|        1|
# +----+---------+---------+
# |   7|        1|        1|
# +----+---------+---------+
# |   8| 0.999722| 0.989444|
# +----+---------+---------+
# |   9| 0.999722| 0.989444|
# +----+---------+---------+
# |  10|        1| 0.991667|
# +----+---------+---------+
# |  11| 0.995278| 0.967222|
# +----+---------+---------+
# |  12|   0.9975| 0.983333|
# +----+---------+---------+
# |  13| 0.995278| 0.953889|
# +----+---------+---------+
# |  14| 0.995556| 0.962222|
# +----+---------+---------+
# |  15| 0.995278| 0.938889|
# +----+---------+---------+
# |  16| 0.995556| 0.949444|
# +----+---------+---------+
# |  17| 0.995278| 0.922778|
# +----+---------+---------+
# |  18| 0.995278|     0.94|
# +----+---------+---------+
# |  19| 0.995278|    0.915|
# +----+---------+---------+
# |  20| 0.995278| 0.911111|
# +----+---------+---------+
# |  21| 0.995278| 0.909444|
# +----+---------+---------+
# |  22| 0.995278| 0.921667|
# +----+---------+---------+
# |  23| 0.995278| 0.906667|
# +----+---------+---------+
# |  24| 0.995278| 0.893333|
# +----+---------+---------+
# |  25| 0.995278| 0.879444|
# +----+---------+---------+
# |  26| 0.995278| 0.866111|
# +----+---------+---------+
# |  27| 0.995278|    0.865|
# +----+---------+---------+
# |  28| 0.995278| 0.869444|
# +----+---------+---------+
# |  29| 0.995278| 0.846111|
# +----+---------+---------+
# |  30| 0.995278| 0.837222|
# +----+---------+---------+
# |  31| 0.995278| 0.847222|
# +----+---------+---------+
# |  32| 0.995278| 0.833333|
# +----+---------+---------+
# |  33| 0.995278| 0.836111|
# +----+---------+---------+
# |  34| 0.995278| 0.831111|
# +----+---------+---------+
# |  35| 0.995278| 0.834444|
# +----+---------+---------+
# |  36| 0.995278| 0.822222|
# +----+---------+---------+
# |  37| 0.995278| 0.842222|
# +----+---------+---------+
# |  38| 0.995278| 0.818333|
# +----+---------+---------+
# |  39| 0.995278|     0.81|
# +----+---------+---------+
# |  40| 0.995278|    0.815|
# +----+---------+---------+
# |  41| 0.995278| 0.793333|
# +----+---------+---------+
# |  42| 0.995278| 0.782778|
# +----+---------+---------+
# |  43| 0.995278|    0.805|
# +----+---------+---------+
# |  44| 0.995278| 0.752778|
# +----+---------+---------+
# |  45| 0.995278| 0.776667|
# +----+---------+---------+
# |  46| 0.995278| 0.757222|
# +----+---------+---------+
# |  47| 0.995278| 0.766667|
# +----+---------+---------+
# |  48| 0.995278| 0.743333|
# +----+---------+---------+
# |  49| 0.995278| 0.740556|
# +----+---------+---------+
# |  50| 0.995278| 0.730556|
# +----+---------+---------+
# |  51| 0.995278| 0.718889|
# +----+---------+---------+
# |  52| 0.995278| 0.727222|
# +----+---------+---------+
# |  53| 0.995278| 0.718333|
# +----+---------+---------+
# |  54| 0.995278| 0.696111|
# +----+---------+---------+
# |  55| 0.995278| 0.692222|
# +----+---------+---------+
# |  56| 0.995278| 0.678889|
# +----+---------+---------+
# |  57| 0.995278| 0.666667|
# +----+---------+---------+
# |  58| 0.995278| 0.661667|
# +----+---------+---------+
# |  59| 0.995278| 0.688333|
# +----+---------+---------+
# |  60| 0.995278| 0.665556|
# +----+---------+---------+
# |  61| 0.995278| 0.643889|
# +----+---------+---------+
# |  62| 0.995278| 0.615556|
# +----+---------+---------+
# |  63| 0.995278| 0.604444|
# +----+---------+---------+
# |  64| 0.995278| 0.621667|
# +----+---------+---------+
# |  65| 0.995278| 0.623333|
# +----+---------+---------+
# |  66| 0.995278| 0.607222|
# +----+---------+---------+
# |  67| 0.995278| 0.601111|
# +----+---------+---------+
# |  68| 0.995278| 0.586667|
# +----+---------+---------+
# |  69| 0.995278|    0.565|
# +----+---------+---------+
# |  70| 0.995278| 0.564444|
# +----+---------+---------+
# |  71| 0.995278| 0.549444|
# +----+---------+---------+
# |  72| 0.995278| 0.537222|
# +----+---------+---------+
# |  73| 0.995278| 0.531667|
# +----+---------+---------+
# |  74| 0.995278| 0.538889|
# +----+---------+---------+
# |  75| 0.995278| 0.528333|
# +----+---------+---------+
# |  76| 0.995278| 0.536111|
# +----+---------+---------+
# |  77| 0.995278| 0.549444|
# +----+---------+---------+
# |  78| 0.995278|     0.55|
# +----+---------+---------+
# |  79| 0.995278|     0.52|
# +----+---------+---------+
# |  80| 0.995278| 0.507222|
# +----+---------+---------+
# |  81| 0.995278| 0.468333|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 1 hours 58 minutes 1 seconds.
#
# ===== TRAINING 7-stage =====
# <BEGIN
# POS count : consumed   3600 : 3726
# NEG count : acceptanceRatio    1800 : 0.0294691
# Precalculation time: 25
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2|        1|        1|
# +----+---------+---------+
# |   3|        1|        1|
# +----+---------+---------+
# |   4|        1|        1|
# +----+---------+---------+
# |   5|        1|        1|
# +----+---------+---------+
# |   6|        1|        1|
# +----+---------+---------+
# |   7| 0.995833| 0.964444|
# +----+---------+---------+
# |   8| 0.997778| 0.978333|
# +----+---------+---------+
# |   9| 0.995278| 0.962778|
# +----+---------+---------+
# |  10| 0.995556| 0.962222|
# +----+---------+---------+
# |  11| 0.996111| 0.971667|
# +----+---------+---------+
# |  12| 0.997222| 0.972222|
# +----+---------+---------+
# |  13| 0.995278| 0.953889|
# +----+---------+---------+
# |  14| 0.995278| 0.941111|
# +----+---------+---------+
# |  15| 0.995278| 0.938889|
# +----+---------+---------+
# |  16| 0.996111| 0.943333|
# +----+---------+---------+
# |  17| 0.995556| 0.939444|
# +----+---------+---------+
# |  18| 0.995278|    0.925|
# +----+---------+---------+
# |  19| 0.995278| 0.902778|
# +----+---------+---------+
# |  20| 0.995278| 0.896111|
# +----+---------+---------+
# |  21| 0.995278| 0.881667|
# +----+---------+---------+
# |  22| 0.995278| 0.900556|
# +----+---------+---------+
# |  23| 0.995278| 0.883333|
# +----+---------+---------+
# |  24| 0.995278| 0.889444|
# +----+---------+---------+
# |  25| 0.995278|    0.885|
# +----+---------+---------+
# |  26| 0.995278| 0.863333|
# +----+---------+---------+
# |  27| 0.995278| 0.857778|
# +----+---------+---------+
# |  28| 0.995278| 0.851111|
# +----+---------+---------+
# |  29| 0.995278| 0.851111|
# +----+---------+---------+
# |  30| 0.995278| 0.836111|
# +----+---------+---------+
# |  31| 0.995278| 0.849444|
# +----+---------+---------+
# |  32| 0.995278| 0.852778|
# +----+---------+---------+
# |  33| 0.995278| 0.848889|
# +----+---------+---------+
# |  34| 0.995278| 0.842778|
# +----+---------+---------+
# |  35| 0.995278| 0.842222|
# +----+---------+---------+
# |  36| 0.995278| 0.829444|
# +----+---------+---------+
# |  37| 0.995278| 0.832778|
# +----+---------+---------+
# |  38| 0.995278| 0.824444|
# +----+---------+---------+
# |  39| 0.995278| 0.803889|
# +----+---------+---------+
# |  40| 0.995278| 0.802222|
# +----+---------+---------+
# |  41| 0.995278| 0.783889|
# +----+---------+---------+
# |  42| 0.995278| 0.772222|
# +----+---------+---------+
# |  43| 0.995278| 0.781667|
# +----+---------+---------+
# |  44| 0.995278| 0.756667|
# +----+---------+---------+
# |  45| 0.995278| 0.788333|
# +----+---------+---------+
# |  46| 0.995278| 0.772778|
# +----+---------+---------+
# |  47| 0.995278| 0.761111|
# +----+---------+---------+
# |  48| 0.995278| 0.742778|
# +----+---------+---------+
# |  49| 0.995278| 0.772222|
# +----+---------+---------+
# |  50| 0.995278| 0.752778|
# +----+---------+---------+
# |  51| 0.995278| 0.722778|
# +----+---------+---------+
# |  52| 0.995278|    0.745|
# +----+---------+---------+
# |  53| 0.995278| 0.724444|
# +----+---------+---------+
# |  54| 0.995278| 0.721667|
# +----+---------+---------+
# |  55| 0.995278| 0.692778|
# +----+---------+---------+
# |  56| 0.995278|    0.685|
# +----+---------+---------+
# |  57| 0.995278| 0.692778|
# +----+---------+---------+
# |  58| 0.995278| 0.676667|
# +----+---------+---------+
# |  59| 0.995278| 0.666667|
# +----+---------+---------+
# |  60| 0.995278| 0.659444|
# +----+---------+---------+
# |  61| 0.995278| 0.654444|
# +----+---------+---------+
# |  62| 0.995278| 0.678333|
# +----+---------+---------+
# |  63| 0.995278| 0.672778|
# +----+---------+---------+
# |  64| 0.995278| 0.641667|
# +----+---------+---------+
# |  65| 0.995278| 0.612778|
# +----+---------+---------+
# |  66| 0.995278| 0.619444|
# +----+---------+---------+
# |  67| 0.995278| 0.605556|
# +----+---------+---------+
# |  68| 0.995278| 0.592222|
# +----+---------+---------+
# |  69| 0.995278| 0.599444|
# +----+---------+---------+
# |  70| 0.995278| 0.617222|
# +----+---------+---------+
# |  71| 0.995278| 0.635556|
# +----+---------+---------+
# |  72| 0.995278| 0.591111|
# +----+---------+---------+
# |  73| 0.995278| 0.610556|
# +----+---------+---------+
# |  74| 0.995278| 0.605556|
# +----+---------+---------+
# |  75| 0.995278| 0.606111|
# +----+---------+---------+
# |  76| 0.995278| 0.580556|
# +----+---------+---------+
# |  77| 0.995278| 0.577222|
# +----+---------+---------+
# |  78| 0.995278|    0.575|
# +----+---------+---------+
# |  79| 0.995278| 0.558889|
# +----+---------+---------+
# |  80| 0.995278| 0.572778|
# +----+---------+---------+
# |  81| 0.995278| 0.577778|
# +----+---------+---------+
# |  82| 0.995278|    0.575|
# +----+---------+---------+
# |  83| 0.995278|     0.56|
# +----+---------+---------+
# |  84| 0.995278| 0.552778|
# +----+---------+---------+
# |  85| 0.995278| 0.536667|
# +----+---------+---------+
# |  86| 0.995278| 0.512778|
# +----+---------+---------+
# |  87| 0.995278| 0.510556|
# +----+---------+---------+
# |  88| 0.995278| 0.532778|
# +----+---------+---------+
# |  89| 0.995278| 0.517222|
# +----+---------+---------+
# |  90| 0.995278| 0.511667|
# +----+---------+---------+
# |  91| 0.995278| 0.495556|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 2 hours 25 minutes 16 seconds.
#
# ===== TRAINING 8-stage =====
# <BEGIN
# POS count : consumed   3600 : 3748
# NEG count : acceptanceRatio    1800 : 0.0205695
# Precalculation time: 23
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2|        1|        1|
# +----+---------+---------+
# |   3|        1|        1|
# +----+---------+---------+
# |   4|        1|        1|
# +----+---------+---------+
# |   5|        1|        1|
# +----+---------+---------+
# |   6|        1|        1|
# +----+---------+---------+
# |   7| 0.998333| 0.978889|
# +----+---------+---------+
# |   8| 0.998889| 0.990556|
# +----+---------+---------+
# |   9| 0.995833| 0.973889|
# +----+---------+---------+
# |  10| 0.995556| 0.973889|
# +----+---------+---------+
# |  11| 0.995833|    0.975|
# +----+---------+---------+
# |  12| 0.995278| 0.946667|
# +----+---------+---------+
# |  13| 0.996944| 0.967222|
# +----+---------+---------+
# |  14| 0.995556|     0.95|
# +----+---------+---------+
# |  15| 0.995278|    0.945|
# +----+---------+---------+
# |  16| 0.995833| 0.932222|
# +----+---------+---------+
# |  17| 0.995278|     0.93|
# +----+---------+---------+
# |  18| 0.995278| 0.926667|
# +----+---------+---------+
# |  19| 0.995278| 0.926667|
# +----+---------+---------+
# |  20| 0.995278| 0.938333|
# +----+---------+---------+
# |  21| 0.995556|    0.935|
# +----+---------+---------+
# |  22| 0.995278| 0.923333|
# +----+---------+---------+
# |  23| 0.995278| 0.917222|
# +----+---------+---------+
# |  24| 0.995278| 0.922222|
# +----+---------+---------+
# |  25| 0.995278| 0.906111|
# +----+---------+---------+
# |  26| 0.995278| 0.891667|
# +----+---------+---------+
# |  27| 0.995278| 0.890556|
# +----+---------+---------+
# |  28| 0.995278| 0.887778|
# +----+---------+---------+
# |  29| 0.995278| 0.867778|
# +----+---------+---------+
# |  30| 0.995278| 0.875556|
# +----+---------+---------+
# |  31| 0.995278| 0.868333|
# +----+---------+---------+
# |  32| 0.995278| 0.852778|
# +----+---------+---------+
# |  33| 0.995278| 0.835556|
# +----+---------+---------+
# |  34| 0.995278| 0.823333|
# +----+---------+---------+
# |  35| 0.995278| 0.828333|
# +----+---------+---------+
# |  36| 0.995278| 0.827778|
# +----+---------+---------+
# |  37| 0.995278| 0.817222|
# +----+---------+---------+
# |  38| 0.995278| 0.829444|
# +----+---------+---------+
# |  39| 0.995278| 0.827222|
# +----+---------+---------+
# |  40| 0.995278| 0.826667|
# +----+---------+---------+
# |  41| 0.995278| 0.820556|
# +----+---------+---------+
# |  42| 0.995278| 0.814444|
# +----+---------+---------+
# |  43| 0.995278| 0.807222|
# +----+---------+---------+
# |  44| 0.995278| 0.798889|
# +----+---------+---------+
# |  45| 0.995278| 0.790556|
# +----+---------+---------+
# |  46| 0.995278| 0.794444|
# +----+---------+---------+
# |  47| 0.995278| 0.785556|
# +----+---------+---------+
# |  48| 0.995278| 0.775556|
# +----+---------+---------+
# |  49| 0.995278| 0.749444|
# +----+---------+---------+
# |  50| 0.995278| 0.754444|
# +----+---------+---------+
# |  51| 0.995278| 0.718333|
# +----+---------+---------+
# |  52| 0.995278| 0.722222|
# +----+---------+---------+
# |  53| 0.995278| 0.722222|
# +----+---------+---------+
# |  54| 0.995278|    0.705|
# +----+---------+---------+
# |  55| 0.995278| 0.691111|
# +----+---------+---------+
# |  56| 0.995278| 0.676111|
# +----+---------+---------+
# |  57| 0.995278| 0.681111|
# +----+---------+---------+
# |  58| 0.995278| 0.672778|
# +----+---------+---------+
# |  59| 0.995278|    0.675|
# +----+---------+---------+
# |  60| 0.995278| 0.661111|
# +----+---------+---------+
# |  61| 0.995278| 0.657778|
# +----+---------+---------+
# |  62| 0.995278| 0.683889|
# +----+---------+---------+
# |  63| 0.995278| 0.676111|
# +----+---------+---------+
# |  64| 0.995278| 0.688333|
# +----+---------+---------+
# |  65| 0.995278| 0.671111|
# +----+---------+---------+
# |  66| 0.995278| 0.653889|
# +----+---------+---------+
# |  67| 0.995278| 0.670556|
# +----+---------+---------+
# |  68| 0.995278| 0.658333|
# +----+---------+---------+
# |  69| 0.995278| 0.656111|
# +----+---------+---------+
# |  70| 0.995278| 0.636111|
# +----+---------+---------+
# |  71| 0.995278| 0.650556|
# +----+---------+---------+
# |  72| 0.995278| 0.658333|
# +----+---------+---------+
# |  73| 0.995278| 0.637778|
# +----+---------+---------+
# |  74| 0.995278| 0.622222|
# +----+---------+---------+
# |  75| 0.995278| 0.612778|
# +----+---------+---------+
# |  76| 0.995278| 0.607778|
# +----+---------+---------+
# |  77| 0.995278| 0.600556|
# +----+---------+---------+
# |  78| 0.995278| 0.572778|
# +----+---------+---------+
# |  79| 0.995278| 0.584444|
# +----+---------+---------+
# |  80| 0.995278| 0.582222|
# +----+---------+---------+
# |  81| 0.995278|    0.575|
# +----+---------+---------+
# |  82| 0.995278| 0.561667|
# +----+---------+---------+
# |  83| 0.995278| 0.556667|
# +----+---------+---------+
# |  84| 0.995278| 0.560556|
# +----+---------+---------+
# |  85| 0.995278| 0.540556|
# +----+---------+---------+
# |  86| 0.995278| 0.541111|
# +----+---------+---------+
# |  87| 0.995278| 0.528333|
# +----+---------+---------+
# |  88| 0.995278| 0.522778|
# +----+---------+---------+
# |  89| 0.995278| 0.536111|
# +----+---------+---------+
# |  90| 0.995278| 0.513889|
# +----+---------+---------+
# |  91| 0.995278| 0.507222|
# +----+---------+---------+
# |  92| 0.995278| 0.517222|
# +----+---------+---------+
# |  93| 0.995278|     0.53|
# +----+---------+---------+
# |  94| 0.995278|    0.515|
# +----+---------+---------+
# |  95| 0.995278| 0.544444|
# +----+---------+---------+
# |  96| 0.995278| 0.529444|
# +----+---------+---------+
# |  97| 0.995278| 0.492222|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 2 hours 55 minutes 2 seconds.
#
# ===== TRAINING 9-stage =====
# <BEGIN
# POS count : consumed   3600 : 3766
# NEG count : acceptanceRatio    1800 : 0.0148098
# Precalculation time: 26
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2|        1|        1|
# +----+---------+---------+
# |   3|        1|        1|
# +----+---------+---------+
# |   4|        1|        1|
# +----+---------+---------+
# |   5|        1|        1|
# +----+---------+---------+
# |   6|        1|        1|
# +----+---------+---------+
# |   7| 0.997222|     0.98|
# +----+---------+---------+
# |   8| 0.995278| 0.943889|
# +----+---------+---------+
# |   9| 0.996389| 0.954444|
# +----+---------+---------+
# |  10| 0.996389| 0.957778|
# +----+---------+---------+
# |  11| 0.995278| 0.956111|
# +----+---------+---------+
# |  12| 0.995278| 0.948889|
# +----+---------+---------+
# |  13| 0.995278|    0.935|
# +----+---------+---------+
# |  14| 0.995278| 0.927222|
# +----+---------+---------+
# |  15| 0.995278| 0.921111|
# +----+---------+---------+
# |  16| 0.995556| 0.915556|
# +----+---------+---------+
# |  17| 0.995556| 0.908889|
# +----+---------+---------+
# |  18| 0.995556| 0.918889|
# +----+---------+---------+
# |  19| 0.995278| 0.908333|
# +----+---------+---------+
# |  20| 0.995278| 0.885556|
# +----+---------+---------+
# |  21| 0.995278| 0.902222|
# +----+---------+---------+
# |  22| 0.995278| 0.884444|
# +----+---------+---------+
# |  23| 0.995278| 0.886667|
# +----+---------+---------+
# |  24| 0.995278|    0.875|
# +----+---------+---------+
# |  25| 0.995278| 0.849444|
# +----+---------+---------+
# |  26| 0.995278| 0.841111|
# +----+---------+---------+
# |  27| 0.995278| 0.829444|
# +----+---------+---------+
# |  28| 0.995278| 0.852222|
# +----+---------+---------+
# |  29| 0.995278| 0.833889|
# +----+---------+---------+
# |  30| 0.995278| 0.831667|
# +----+---------+---------+
# |  31| 0.995278| 0.823889|
# +----+---------+---------+
# |  32| 0.995278| 0.802222|
# +----+---------+---------+
# |  33| 0.995278| 0.812222|
# +----+---------+---------+
# |  34| 0.995556| 0.802778|
# +----+---------+---------+
# |  35| 0.995278| 0.781667|
# +----+---------+---------+
# |  36| 0.995278| 0.797222|
# +----+---------+---------+
# |  37| 0.995278| 0.782778|
# +----+---------+---------+
# |  38| 0.995278|    0.785|
# +----+---------+---------+
# |  39| 0.995278| 0.757778|
# +----+---------+---------+
# |  40| 0.995278| 0.756667|
# +----+---------+---------+
# |  41| 0.995278| 0.779444|
# +----+---------+---------+
# |  42| 0.995278| 0.764444|
# +----+---------+---------+
# |  43| 0.995278| 0.753889|
# +----+---------+---------+
# |  44| 0.995278| 0.731111|
# +----+---------+---------+
# |  45| 0.995278| 0.729444|
# +----+---------+---------+
# |  46| 0.995278| 0.722222|
# +----+---------+---------+
# |  47| 0.995278| 0.707778|
# +----+---------+---------+
# |  48| 0.995278| 0.712778|
# +----+---------+---------+
# |  49| 0.995278| 0.700556|
# +----+---------+---------+
# |  50| 0.995278|    0.685|
# +----+---------+---------+
# |  51| 0.995278| 0.671111|
# +----+---------+---------+
# |  52| 0.995278| 0.676667|
# +----+---------+---------+
# |  53| 0.995278| 0.662778|
# +----+---------+---------+
# |  54| 0.995278| 0.648889|
# +----+---------+---------+
# |  55| 0.995278| 0.648889|
# +----+---------+---------+
# |  56| 0.995278| 0.646667|
# +----+---------+---------+
# |  57| 0.995278| 0.620556|
# +----+---------+---------+
# |  58| 0.995278| 0.610556|
# +----+---------+---------+
# |  59| 0.995278| 0.605556|
# +----+---------+---------+
# |  60| 0.995278| 0.621667|
# +----+---------+---------+
# |  61| 0.995278| 0.616111|
# +----+---------+---------+
# |  62| 0.995278| 0.613889|
# +----+---------+---------+
# |  63| 0.995278| 0.603333|
# +----+---------+---------+
# |  64| 0.995278| 0.589444|
# +----+---------+---------+
# |  65| 0.995278| 0.577222|
# +----+---------+---------+
# |  66| 0.995278| 0.551111|
# +----+---------+---------+
# |  67| 0.995278| 0.557222|
# +----+---------+---------+
# |  68| 0.995278| 0.541667|
# +----+---------+---------+
# |  69| 0.995278| 0.532778|
# +----+---------+---------+
# |  70| 0.995278| 0.543333|
# +----+---------+---------+
# |  71| 0.995278| 0.538889|
# +----+---------+---------+
# |  72| 0.995278| 0.557222|
# +----+---------+---------+
# |  73| 0.995278| 0.533333|
# +----+---------+---------+
# |  74| 0.995278| 0.537778|
# +----+---------+---------+
# |  75| 0.995278| 0.511111|
# +----+---------+---------+
# |  76| 0.995278| 0.497222|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 3 hours 19 minutes 28 seconds.

# %%
# !rm -rf data
# !mkdir data
# !ls
# Out:
#  bg.txt		    gun.png	  neg		     rifel.jpg
#  data		    image.ipynb   positives.vec      ThreadEx.py
#  DownloadImage.py   info	 'Resize Image.py'   uglies
